# %% [markdown]
# ## I wanted to look at the Bexar County's population size per zip code by race/ethnicity. I will be looking at the 4 largest race/ethnicities in Bexar County: Hispanic/Latino, White only, Black/African American only, and Asian only.

# %%
import pandas as pd
# Allows us to make API calls with python
import requests
# json allows us to store the results of the API cleanly
import json

# %% [markdown]
# ### Get list of all zip codes in Bexar County seperated by commas. P.S., I got the list of the Bexar County zips from the internet and saved it to a text file.

# %%
Bexar_zips = open('Bexar_zips.txt', 'r').readlines()
Bexar_zips = [z.replace('\n', '') for z in Bexar_zips]
Bexar_zips = ','.join(Bexar_zips)

# %%
Bexar_zips
# Out:
# '78002,78023,78054,78069,78073,78101,78109,78112,78148,78150,78152,78201,78202,78203,78204,78205,78206,78207,78208,78209,78210,78211,78212,78213,78214,78215,78216,78217,78218,78219,78220,78221,78222,78223,78224,78225,78226,78227,78228,78229,78230,78231,78232,78233,78234,78235,78236,78237,78238,78239,78240,78241,78242,78243,78244,78245,78246,78247,78248,78249,78250,78251,78252,78253,78254,78255,78256,78257,78258,78259,78260,78261,78263,78264,78265,78268,78269,78270,78278,78279,78280,78283,78284,78285,78288,78289,78291,78292,78293,78294,78295,78296,78297,78298,78299'

# %% [markdown]
# ### After requesting and recieving my secret API key from the US Census Bureau, I stored it in here:

# %%
apiKey = 'MY_SECRET_API_KEY'

# %% [markdown]
# ### We now will need to construct the API key we will use. B03001_003E is the name of one of the ACS 5-year data forms I used. This one specifically is the Estimate Total of Hispanic or Latino in a population by zip code.

# %%
baseAPI = "https://api.census.gov/data/2017/acs/acs5?key=%s&get=B03001_003E&for=zip%%20code%%20tabulation%%20area:%s" 
calledAPI = baseAPI % (apiKey, Bexar_zips)

# %% [markdown]
# ### Now we will call the the API and collect the response.

# %%
response = requests.get(calledAPI)

# %% [markdown]
# ### Load the response into a JSON, igonoring the first element which is just field labels.

# %%
formattedResponse = json.loads(response.text)[1:]

# %% [markdown]
# #### This is what we get:

# %%
formattedResponse[:5]
# Out:
# [['22951', '78216'],
#  ['0', '78150'],
#  ['29', '78243'],
#  ['4769', '78069'],
#  ['19300', '78218']]

# %% [markdown]
# ### I want to flip the order of the response from [population,zipcode] -> [zipcode,population].

# %%
formattedResponse = [item[::-1] for item in formattedResponse]

# %%
formattedResponse[:5]
# Out:
# [['78216', '22951'],
#  ['78150', '0'],
#  ['78243', '29'],
#  ['78069', '4769'],
#  ['78218', '19300']]

# %% [markdown]
# ### Store our response into a pandas dataframe.

# %%
BexarZipPopulations = pd.DataFrame(columns=['zipcode','population'],
                                   data= formattedResponse)

# %% [markdown]
# ### Save and export this dataframe into a csv.

# %%
BexarZipPopulations.to_csv('BexarZipPopulationsHispanic.csv', index=False)

# %% [markdown]
# ## After gathering this information for all the other race/ethnicity groups we are evaluating, and putting them into the same csv, we are now ready to insert our information in Tableau. Since Tableau doesn't take csv files, you just need to convert your csv into an xlsx.

# %% [markdown]
# ### Here are the results after mapping our information in Tableau!

# %% [markdown]
# #### Population density for all Hispanic/Latinos, whites, blacks/African Americans, and Asians in Bexar County by zip code.

# %%
from IPython.display import Image
Image(filename='ALLBexarCounty.png')

# %% [markdown]
# #### Population density for all Hispanic/Latinos in Bexar County by zip code. This population looks to be denser in the west, south, and central areas.

# %%
from IPython.display import Image
Image(filename='HispanicBexarCounty.png')

# %% [markdown]
# #### Population density for the White only population in Bexar County by zip code. This population looks to be denser in the north, and southeastern areas.

# %%
from IPython.display import Image
Image(filename='WhiteBexarCounty.png')

# %% [markdown]
# #### Population density for the Black/African American only population in Bexar County by zip code. This population looks to have greater density in the far east and far west areas.

# %%
from IPython.display import Image
Image(filename='BlackBexarCounty.png')

# %% [markdown]
# #### Population density for the Asian only population in Bexar County by zip code. This population looks to have greater density in the north.

# %%
from IPython.display import Image
Image(filename='AsianBexarCounty.png')

# %% [markdown]
# # FIN!
